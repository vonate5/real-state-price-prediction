# %% [markdown]
# # CASE STUDY - REGRESSION
# ## Real Estate

# %% [markdown]
# ## Get the data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Midterm_project_experiment.ipynb        Midterm_project_regression_final.ipynb

# %%
cd
# Out:
# /Users/vonate

# %%
cd Documents
# Out:
# /Users/vonate/Documents

# %%
cd Github
# Out:
# /Users/vonate/Documents/Github

# %%
cd Ironhack
# Out:
# /Users/vonate/Documents/Github/Ironhack

# %%
cd Projects
# Out:
# /Users/vonate/Documents/Github/Ironhack/Projects

# %%
cd MidTerm Project
# Out:
# /Users/vonate/Documents/Github/Ironhack/Projects/MidTerm Project

# %%
ls
# Out:
# final/                regression_data.xls   regression_data3.csv
# regression_data.csv   regression_data1.csv

# %%
df=pd.read_excel('regression_data.xls')

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   bedrooms       21597 non-null  int64
#  3   bathrooms      21597 non-null  float64
#  4   sqft_living    21597 non-null  int64
#  5   sqft_lot       21597 non-null  int64
#  6   floors         21597 non-null  float64
#  7   waterfront     21597 non-null  int64
#  8   view           21597 non-null  int64
#  9   condition      21597 non-null  int64
#  10  grade          21597 non-null  int64
#  11  sqft_above     21597 non-null  int64
#  12  sqft_basement  21597 non-null  int64
#  13  yr_built       21597 non-null  int64
#  14  yr_renovated   21597 non-null  int64
#  15  zipcode        21597 non-null  int64
#  16  lat            21597 non-null  float64
# ...

# %%
df.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %% [markdown]
# ### Data cleaning

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# price            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['id'].value_counts()
# Out:
# 795000620     3
# 1568100300    2
# 2892700041    2
# 1450100390    2
# 3395040550    2
#              ..
# 2595650170    1
# 7212651100    1
# 9808700025    1
# 6772200055    1
# 2424410110    1
# Name: id, Length: 21420, dtype: int64

# %%
# searching for how many repeated id we have
(df['id'].value_counts() >1).sum()
# Out:
# 176

# %%
# this house has been sold twice with different prices
df[df['id'] == 1568100300]

# We are not going to drop it as it's not a problem
# Out:
#               id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 9105  1568100300 2014-09-17         6        4.5         3500      8504
# 9106  1568100300 2015-01-21         6        4.5         3500      8504
#
#       floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 9105     2.0           0     0          3  ...        3500              0
# 9106     2.0           0     0          3  ...        3500              0
#
#       yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 9105      1980             0    98155  47.7351 -122.295           1550
# 9106      1980             0    98155  47.7351 -122.295           1550
#
#       sqft_lot15   price
# 9105        8460  350000
# 9106        8460  682500
#
# [2 rows x 21 columns]

# %%
df['date']=df['date'].apply(lambda x: x.toordinal())
df.head()
# Out:
#            id    date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  735519         3       1.00         1180      5650     1.0
# 1  6414100192  735576         3       2.25         2570      7242     2.0
# 2  5631500400  735654         2       1.00          770     10000     1.0
# 3  2487200875  735576         4       3.00         1960      5000     1.0
# 4  1954400510  735647         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# ...

# %%
df.dtypes
# Out:
# id                 int64
# date               int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# price              int64
# dtype: object

# %% [markdown]
# ### EDA - Explore Data

# %%
df.corr()
# Out:
#                      id      date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000  0.005385  0.001150   0.005162    -0.012241 -0.131911
# date           0.005385  1.000000 -0.016523  -0.034236    -0.034276  0.006337
# bedrooms       0.001150 -0.016523  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162 -0.034236  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241 -0.034276  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.006337  0.032471   0.088373     0.173453  1.000000
# floors         0.018608 -0.022333  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.001365 -0.006834   0.063744     0.103854  0.021632
# view           0.011536 -0.001726  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803 -0.050883  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188 -0.039773  0.356563   0.665838     0.762779  0.114731
# ...

# %%
corr_matrix = df.corr()

# %%
fig, ax = plt.subplots(figsize=(30,30))
sns.heatmap(corr_matrix,
           cmap='seismic',
           center=0,
           annot=True,
           );

# %%
df.drop(['id', 'sqft_above', 'sqft_lot15', 'sqft_living15', 'sqft_lot'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      date  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0  735519         3       1.00         1180     1.0           0     0
# 1  735576         3       2.25         2570     2.0           0     0
# 2  735654         2       1.00          770     1.0           0     0
# 3  735576         4       3.00         1960     1.0           0     0
# 4  735647         3       2.00         1680     1.0           0     0
#
#    condition  grade  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0          3      7              0      1955             0    98178  47.5112
# 1          3      7            400      1951          1991    98125  47.7210
# 2          3      6              0      1933             0    98028  47.7379
# 3          5      7            910      1965             0    98136  47.5208
# 4          3      8              0      1987             0    98074  47.6168
#
#       long   price
# 0 -122.257  221900
# 1 -122.319  538000
# 2 -122.233  180000
# ...

# %% [markdown]
# ### Linear Regression Model

# %%
#import the model from sklearn
from sklearn import linear_model
#import evaluation metrics from sklearn
from sklearn.metrics import mean_squared_error,r2_score
#import TTsplit from sklearn
from sklearn.model_selection import train_test_split
#import linearregregression
from sklearn.linear_model import LinearRegression

# %%
y=df['price'] # DEPENDENT VAR/LABEL
X=df.drop(['price'], axis=1) # INDEPENDENT VAR/LABEL

# %%
# 60% of the data to the train and 40% to the test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=40)

# %%
lm = LinearRegression()
model = lm.fit(X_train,y_train)

# %%
y_pred= lm.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.702741228662985

# %%
# dropping long and lat because we have the zipcode
df = df.drop(['lat', 'long'], axis=1)

# %%
df.describe()
# Out:
#                 date      bedrooms     bathrooms   sqft_living        floors  \
# count   21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean   735535.180997      3.373200      2.115826   2080.321850      1.494096
# std       113.059987      0.926299      0.768984    918.106125      0.539683
# min    735355.000000      1.000000      0.500000    370.000000      1.000000
# 25%    735436.000000      3.000000      1.750000   1430.000000      1.000000
# 50%    735522.000000      3.000000      2.250000   1910.000000      1.500000
# 75%    735646.000000      4.000000      2.500000   2550.000000      2.000000
# max    735745.000000     33.000000      8.000000  13540.000000      3.500000
#
#          waterfront          view     condition         grade  sqft_basement  \
# count  21597.000000  21597.000000  21597.000000  21597.000000   21597.000000
# mean       0.007547      0.234292      3.409825      7.657915     291.725008
# ...

# %%
Xnum = df[['bedrooms','bathrooms','sqft_living','floors', 'sqft_basement', 'yr_built', 'yr_renovated']]

# %%
Xcat = df[['waterfront', 'view', 'condition', 'grade', 'zipcode']]

# %%
Xnum.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  sqft_basement  yr_built  \
# 0         3       1.00         1180     1.0              0      1955
# 1         3       2.25         2570     2.0            400      1951
# 2         2       1.00          770     1.0              0      1933
# 3         4       3.00         1960     1.0            910      1965
# 4         3       2.00         1680     1.0              0      1987
#
#    yr_renovated
# 0             0
# 1          1991
# 2             0
# 3             0
# 4             0

# %%
Xcat.head()
# Out:
#    waterfront  view  condition  grade  zipcode
# 0           0     0          3      7    98178
# 1           0     0          3      7    98125
# 2           0     0          3      6    98028
# 3           0     0          5      7    98136
# 4           0     0          3      8    98074

# %%
# option 1 standardising all numeric features / rescaling using Normalizer

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(Xnum, alpha=0.2, figsize=(15,15), diagonal='kde');

# %%
from sklearn.preprocessing import Normalizer
transformer=Normalizer().fit(Xnum)
X_normalized=transformer.transform(Xnum)

# %%
X_normalized
# Out:
# array([[1.31376469e-03, 4.37921562e-04, 5.16747443e-01, ...,
#         0.00000000e+00, 8.56136654e-01, 0.00000000e+00],
#        [7.86878646e-04, 5.90158985e-04, 6.74092707e-01, ...,
#         1.04917153e-01, 5.11733413e-01, 5.22225128e-01],
#        [9.61205816e-04, 4.80602908e-04, 3.70064239e-01, ...,
#         0.00000000e+00, 9.29005421e-01, 0.00000000e+00],
#        ...,
#        [8.87663264e-04, 3.32873724e-04, 4.52708265e-01, ...,
#         0.00000000e+00, 8.91657749e-01, 0.00000000e+00],
#        [1.16987427e-03, 9.74895223e-04, 6.23932943e-01, ...,
#         0.00000000e+00, 7.81476011e-01, 0.00000000e+00],
#        [8.88014674e-04, 3.33005503e-04, 4.52887484e-01, ...,
#         0.00000000e+00, 8.91566733e-01, 0.00000000e+00]])

# %%
X_norm=pd.DataFrame(X_normalized,columns=
                    ['bedrooms','bathrooms','sqft_living','floors', 
                     'sqft_basement', 'yr_built', 'yr_renovated'])

# %%
scatter_matrix(X_norm, alpha=0.2, figsize=(15,15), diagonal='kde');

# %%
#option 2 standardising all numeric features / rescaling using Standard Scaler

from sklearn.preprocessing import StandardScaler
transformer=StandardScaler().fit(Xnum)
X_standardised=transformer.transform(Xnum)

# %%
X_standardised
# Out:
# array([[-0.40290302, -1.45107268, -0.98065209, ..., -0.65903091,
#         -0.54467809, -0.21020965],
#        [-0.40290302,  0.17448579,  0.53336915, ...,  0.24460216,
#         -0.68085037,  4.74484229],
#        [-1.48249316, -1.45107268, -1.4272339 , ..., -0.65903091,
#         -1.29362563, -0.21020965],
#        ...,
#        [-1.48249316, -1.77618438, -1.15492792, ..., -0.65903091,
#          1.29364769, -0.21020965],
#        [-0.40290302,  0.49959749, -0.52317805, ..., -0.65903091,
#          1.12343234, -0.21020965],
#        [-1.48249316, -1.77618438, -1.15492792, ..., -0.65903091,
#          1.25960462, -0.21020965]])

# %%
X_std=pd.DataFrame(X_standardised,columns=['bedrooms','bathrooms','sqft_living','floors', 
                     'sqft_basement', 'yr_built', 'yr_renovated'])

# %%
scatter_matrix(X_std, alpha=0.2, figsize=(15,15), diagonal='kde');

# %%
# we are using X_normalized

# %%
X = np.concatenate((X_normalized, Xcat), axis=1)

# %%
Xnum.shape
# Out:
# (21597, 7)

# %%
Xcat.shape
# Out:
# (21597, 5)

# %%
X.shape
# Out:
# (21597, 12)

# %%
y.shape
# Out:
# (21597,)

# %% [markdown]
# ### Accuracy with the Normalized Option

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
lm=linear_model.LinearRegression() # configure model
model=lm.fit(X_train,y_train) #train model
predictions=lm.predict(X_test) #set up prediction method
r2_score(y_test,predictions) #calculate my accuracy
# Out:
# 0.5720628945590504

# %% [markdown]
# ### Accuracy with the standardization Option

# %%
X = np.concatenate((X_std, Xcat), axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
lm=linear_model.LinearRegression() # configure model
model=lm.fit(X_train,y_train) #train model
predictions=lm.predict(X_test) #set up prediction method
r2_score(y_test,predictions) #calculate my accuracy
# Out:
# 0.6392667395421092
